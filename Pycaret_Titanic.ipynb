# %% [markdown]
# # Pycaret

# %%
import pandas as pd

# %%
datos_limpios = pd.read_csv('data_train_clean_final.csv')

# %%
from pycaret.classification import *

# %%
exp_clf = setup(data=datos_limpios, target='survived', session_id=42, preprocess=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7edfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7edfc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7edfc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7edfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7edfc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7edfc_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_7edfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7edfc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7edfc_row1_col1" class="data row1 col1" >survived</td>
#     </tr>
#     <tr>
#       <th id="T_7edfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7edfc_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_cdea3 th {
#   text-align: left;
# }
# ...

# %%
final_model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_852c7_row10_col0, #T_852c7_row10_col1, #T_852c7_row10_col2, #T_852c7_row10_col3, #T_852c7_row10_col4, #T_852c7_row10_col5, #T_852c7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_852c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_852c7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_852c7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_852c7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_852c7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_852c7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_852c7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_852c7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_model = tune_model(final_model)
# Out:
# <style type="text/css">
# #T_ff379_row10_col0, #T_ff379_row10_col1, #T_ff379_row10_col2, #T_ff379_row10_col3, #T_ff379_row10_col4, #T_ff379_row10_col5, #T_ff379_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ff379">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff379_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ff379_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ff379_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ff379_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ff379_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ff379_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ff379_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# #### Utilizo Pycaret luego de pre procesar mi dataset para ver que modelos se adecuan más a los datos. En este caso utilizaré Gradient Boosting Classifier para predecir los resultados.¶
# #### Mejoraron los resultados en la matriz de confusión al realizar Oversampling, ajustando el balanceo de datos de la variable objetivo
